# %% [markdown]
# #LLM Cost Optimization :

# %% [markdown]
# ####1. Use Smaller Models

# %%
Don't use GPT-5, Claude Opus, or Gemini Pro for every request.

Many tasks can be handled by:

GPT-4o-mini
Gemini Flash
Claude Haiku
Llama 3 8B
Mistral 7B

# %% [markdown]
# ####Multi-Model Routing

# %%
Route requests based on complexity.

Simple questions → Small model

Complex reasoning → Large model

# %% [markdown]
# ####Quantization :

# %%
## For opensource models

# %% [markdown]
# ####2. Context Trimming

# %%
Every token costs money.

Most conversation history becomes irrelevant.

# Keep only relevant messages.

# %%
-- Conversation Summarization : Replace long chat history with summary.

# %% [markdown]
# ####Output Token Limits

# %%
Models love long answers.

More output = More cost.

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    max_tokens=100
)

# %% [markdown]
# ####3. Response Caching

# %%
Same question = Same answer.

Don't call LLM again.

# %% [markdown]
# ## A2A :

# %%
HTTP/HTTPS  -->
MCP         -->

# %%
A2A  --> Agent 2 Agent protocol :

# %%
Langchain :
Langgraph :
CrewAI :

# %%
Agent1  --MCP --> Tool1
        --MCP --> Tool2


Agent2 --MCP --> Tool1
       --MCP --> Tool2
       --MCP --> Tool3

# %%
Agent1  --A2A--> agent2

# %%
Server  : Hosted Agent
Client  : Communicating to server

# %%
## pip install a2a-sdk
